# %% [markdown]
# # UNIVERSIDAD NACIONAL DE HURLINGHAM
# ## Inst. de Tecnología e Ingeniería
# ### PARSEO Y GENERACIÓN DE CÓDIGO
# #### Prof: Mag. Ing. Pablo Pandolfo
# #### Recuperatorio - Noviembre 2025

# %% [markdown]
# * **ALUMNO**:
# * **DNI**:

# %% [markdown]
# #### NOTA: EL EXAMEN ESCRITO ES UN DOCUMENTO DE GRAN IMPORTANCIA PARA LA EVALUACIÓN DE LOS CONOCIMIENTOS ADQUIRIDOS, POR LO TANTO, SE SOLICITA LEER ATENTAMENTE LO SIGUIENTE
#
# * Responda claramente cada punto, detallando con la mayor precisión posible lo solicitado.
# * Sea prolijo y ordenado en el desarrollo de los temas.
# * Sea cuidadoso con las faltas de ortografía y sus oraciones.
# * No desarrollar el examen en lápiz.
# * Aprobación del examen: Con nota mayor o igual a 4 (cuatro)
# * Condiciones de aprobación: 60%
# * Duración de examen: 3 horas.

# %% [markdown]
# 1. **[2.5 puntos]** Diséñese el diagrama de transiciones para un scanner del lenguaje Colchita Avanzado. [Ver]( https://github.com/ppandomail/lp/blob/main/doc/04-sintaxis.ipynb)

# %% [markdown]
# * a
# * b
# * name = LL*
# * girar
# * (
# * )
# * coser
# * ,
# * let
# * in
# * end
# * fun
# * =
# * val

# %% [markdown]
# 2. **[1.5 puntos]** Impleméntese scanner en Ply

# %% [markdown]
# 3. **[2.5 puntos]** Diséñese una GIC LL(1) entre 7 y 10 producciones, mostrando los conjuntos PRIM, SIG y PRED

# %% [markdown]
# 4. **[1.5 puntos]** Muéstrese los movimientos realizados por el ASDP LL(1) para una determinada entrada

# %% [markdown]
# 5. **[2 puntos]** Constrúyase un cuadro, enumerando diferencias entre Tabla de Tipos y Tabla de Símbolos
